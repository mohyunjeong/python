# %% [markdown]
# ### 🟥 연산자의 종류 🟥
# 1. 산술 연산자 : +, -, *, /, //, %
# 2. 지수 연산자 : **
# 3. 대입(복합) 연산자 : =. +=, -=, *=, /=, //=, %=
# 4. 관계(비교) 연산자 : >, <, >=, <=, ==, != --> 비교를 통한 결과가 참 혹은 거짓으로
# 5. 논리 연산자 : and, or, not
# 6. 삼항 연산자 : a if 조건식 else b
# 7. 멤버 연산자 : in, not in

# %% [markdown]
# #### 🟧 산술 연산자 🟧
# ![image.png](attachment:image.png)

# %%
# 🟨 나누기, 나머지, 나누기(몫) 구하기 🟨
num1 = 10
num2 = 7

print('나누기 :', num1 / num2)
print('나머지 :', num1 % num2)
print('몫 :', num1 // num2)
# Out:
# 나누기 : 1.4285714285714286
# 나머지 : 3
# 몫 : 1

# %% [markdown]
# - 🟨 문자열 더하기 🟨

# %%
str1 = '안녕'
str2 = '하세요~'

print(str1 + str2) # + : 연결 연산
# Out:
# 안녕하세요~

# %%
num1 = '10'
num2 = '7'

print(num1 + num2) # 문자에서는 +가 연결 연산
# Out:
# 107

# %%
num1 = 10
num2 = 7

print(num1 + num2) # 숫자에서는 +가 덧셈
# Out:
# 17

# %% [markdown]
# - 🟩 숫자와 문자를 더하면? 🟩

# %%
num1 = 10
num2 = '7'

print(num1 + num2) # error!

# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# 자료형이 달라서 덧셈이 불가능!!
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 num1 = 10
#       2 num2 = '7'
# ----> 4 print(num1 + num2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# ⭐⭐⭐ 연산이 되게 하려면??? ⭐⭐⭐
# 자료형을 변환해줘야 함 (형변환)

# 🟦 둘 다 숫자형 🟦
print('num1 :', type(num1))
print('num2 :', type(num2))

num2_int = int(num2)

print('num2_int :', type(num2_int))
print('num1 + num2 = ', num1 + num2_int)
# Out:
# num1 : <class 'int'>
# num2 : <class 'str'>
# num2_int : <class 'int'>
# num1 + num2 =  17

# %%
# 🟦 둘 다 문자형으로 -> 연결 연산 🟦
print('num1 :', type(num1))
print('num2 :', type(num2))

num1_str = str(num1)

print('num1_str :', type(num1_str))
print('num1 + num2 =', num1_str + num2)
# Out:
# num1 : <class 'int'>
# num2 : <class 'str'>
# num1_str : <class 'str'>
# num1 + num2 =  107

# %% [markdown]
# - 🟩 산술 연산 예제 🟩
# 1. 🟦 num1 = 23, num2 = 3 대입하고, 더하기, 빼기, 곱하기, 나누기, 몫의 결과를 출력하시오. 🟦

# %%
num1 = 23
num2 = 3

print(f"더하기 결과 : {num1 + num2}")
print(f"빼기 결과 : {num1 - num2}")
print(f"곱하기 결과 : {num1 * num2}")
print(f"나누기 결과 : {num1 / num2}")
print(f"몫 결과 : {num1 // num2}")
# Out:
# 더하기 결과 : 26
# 빼기 결과 : 20
# 곱하기 결과 : 69
# 나누기 결과 : 7.666666666666667
# 몫 결과 : 7

# %%
# 🟪 사용자에게 원하는 값을 입력 받을 수 있도록 하는 함수 -> input() 🟪
a = input('값을 입력하세요 >> ')
print()
print(a)
print(type(a))
# Out:
# 값을 입력하세요 >> 5
#
# 5
# <class 'str'>

# %%
# 🟪 input 함수를 이용해서 값을 입력받은 후 계산할 수 있도록 코딩 🟪
num1 = int(input('첫번째 값을 입력하세요 >> '))
num2 = int(input('두번째 값을 입력하세요 >> '))

print(f"\n더하기 결과 : {num1 + num2}")
print(f"빼기 결과 : {num1 - num2}")
print(f"곱하기 결과 : {num1 * num2}")
print(f"나누기 결과 : {num1 / num2}")
print(f"몫 결과 : {num1 // num2}")
# Out:
# 첫번째 값을 입력하세요 >> 5
# 두번째 값을 입력하세요 >> 1
#
# 더하기 결과 : 6
# 빼기 결과 : 4
# 곱하기 결과 : 5
# 나누기 결과 : 5.0
# 몫 결과 : 5

# %% [markdown]
# 2. 🟦 Python, 머신러닝, 딥러닝 점수를 키보드로 입력받아 합계와 평균을 출력해주는 프로그램을 만들어보자. 🟦

# %%
p = int(input('Pytho 점수 >> '))
ml = int(input('Machine Learning 점수 >> '))
dl = int(input('Deep Learning 점수 >> '))

print(f'\n합계 : {p + ml + dl}')
print(f'평균 : {(p + ml + dl) / 3}')
# Out:
# Pytho 점수 >> 10
# Machine Learning 점수 >> 20
# Deep Learning 점수 >> 30
#
# 합계 : 60
# 평균 : 20.0

# %% [markdown]
# 3. 🟦 변수 num1과 num2에 정수 2개를 입력 받고, 변수 cal에 + 연산자를 입력 받아 더하기 연산을 하는 계산기 프로그램을 만들어보자 🟦
# ![image.png](attachment:image.png)

# %%
print('-'*10+'연산하기'+'-'*10)

num1 = int(input('정수 입력1 >> '))
num2 = int(input('정수 입력2 >> '))
cal = input('더하기 연산자 입력 >> ')

print(f'\n{num1} {cal} {num2} = {num1 + num2}') # 덧셈 결과 출력
# Out:
# ----------연산하기----------
# 정수 입력1 >> 1
# 정수 입력2 >> 2
# 더하기 연산자 입력 >> +
#
# 1 + 2 = 3

# %% [markdown]
# 4. 🟦 초를 입력 받아서 "00시간 00분 00초" 형태로 출력하시오 🟦
# ![image.png](attachment:image.png)

# %%
# 🟪 방법1 🟪
time = int(input("시간 입력 >> "))

# 1시간은 3600초이기 때문에
hour = time // 3600
minute = (time % 3600) // 60
second = time % 60

print(f"\n{hour}시간 {minute}분 {second}초")
# Out:
# 시간 입력 >> 7533
#
# 2시간 5분 33초

# %%
# 🟪 방법2 🟪
time = int(input("시간 입력 >> "))

hour = time // 3600
minute = (time // 60) - (hour * 60) # 시간을 분으로 바꿔 계산
second = time - ((minute * 60) + (hour * 3600)) # 시간과 분을 초로 바꿔 계산

print(f"\n{hour}시간 {minute}분 {second}초")
# Out:
# 시간 입력 >> 3723
#
# 1시간 2분 3초

# %% [markdown]
# - 🟨 문자열 곱하기 🟨

# %%
s = 'x'

print(s * 10) # 문자열에 곱셉을 하면 문자가 반복되어서 출력!
# Out:
# xxxxxxxxxx

# %%
s = '안녕하세요'

print(s * 10)
# Out:
# 안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요

# %% [markdown]
# - 🟧 지수 연산자(기호: **) 🟧

# %%
# 🟨 숫자 2의 3제곱을 계산해보자 🟨 
2 ** 3 # 연산자 우측에 위치하는 수 --> 지수
# Out:
# 8

# %% [markdown]
# ### 🟧 대입(복합) 연산자 🟧
# - 복합 대입 연산자

# %%
num = 3
num = num + 3

print(num)

num = num + 3

print(num)
# Out:
# 6
# 9

# %%
# 🟨 더하면서 갱신 🟨
num = 3
num += 3 # num = num + 3

print(num)
# Out:
# 6

# %%
# 🟨 빼면서 갱신 🟨
num = 100

print(num)

num -= 35 # num = num - 35

print(num)
# Out:
# 100
# 65

# %%
# 🟩 복합 대입 연산자는 +, - *, l, ll, % 전부 사용 가능 🟩

# %% [markdown]
# #### 🟨 치환! : 자리를 바꾸다. 🟨
# - A와 B는 각각 볼펜을 들고 있다. A는 빨간색 펜, B는 파란색 펜을 들고 있을 때 들고 있는 손만을 이용해서 A는 파란색, B는 빨간색 펜을 가질 수 있도록 하려면 어떻게 해야할까?

# %%
a = 3
b = 7

# 🟩 치환 방법 1 🟩
# a에는 데이터(7)이, b에는 데이터(3)이 담기도록

temp = a
a = b
b = temp

print(a)
print(b)
# Out:
# 7
# 3

# %%
# 🟩 치환 방법 2 🟩
# 파이썬은 쉽고 간편해요!

a = 3
b = 7

print(f'a:{a}')
print(f'b:{b}')

a, b = b, a

print(f'\na:{a}')
print(f'b:{b}')
# Out:
# a:3
# b:7
#
# a:7
# b:3

# %% [markdown]
# ### 🟧 비교 연산자 🟧
# - 종류 : >, <, <=, >=, ==, !=

# %%
a = 3
b = 7

print(a > b)
print(a <= b) # 항상 등호가 오른쪽에 있어야 함(<=, >= !=)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True

# %% [markdown]
# - 🟨 비교 연산자 예제 🟨
# - Random 라이브러리(모듈)를 가져와서 2개의 난수를 각각 변수에 넣고, 비교 연산자를 이용하여 출력 값을 확인해보자.

# %%
# import : 불러오기
import random
# random이라는 라이브러리를 불러와서 사용하겠다!

# %%
random.randint(1, 10)
# random,randint(범위 시작값, 범위 끝값)
# 시작값 포함 0, 끝값 포함 0
# Out:
# 1

# %%
a = random.randint(1, 10)
b = random.randint(1, 10)

print(f'난수 생성 >> a : {a}, b : {b}')
print(a < b)
print(a > b)
print(a == b)
print(a != b)
# Out:
# 난수 생성 >> a : 4, b : 5
# True
# False
# False
# True

# %% [markdown]
# ### 🟧 논리 연산자 🟧
# - True, False의 논리값(boolean값)을 반환하는 연산자

# %% [markdown]
# - 🟨 not 연산자 🟨

# %%
a = 3
b = 7

print(f'a < b : {a < b}')
print(f'not a < b : {not a < b}') # not : 부정연산자 -> True or False의 반대 값 출력
# Out:
# a < b : True
# not a < b : False

# %% [markdown]
# - 🟨 and 연산자 : 두 조건이 모두 참(True)일 경우에만 참을 반환 🟨

# %%
print(3 > 5) # --> False
print(10 == 20) # --> False

# 🟩 둘 다 False 🟩

print(3 > 5 and 10 == 20) # False
# Out:
# False
# False
# False

# %%
print(3 < 5) # --> True
print(10 == 20) # --> False

# 🟩하나만 True 🟩

print(3 < 5 and 10 == 20) # False
# Out:
# True
# False
# False

# %%
print(3 < 5) # --> True
print(10 != 20) # --> True

# 🟩 둘 다 True 🟩

print(3 < 5 and 10 != 20) # True
# Out:
# True
# True
# True

# %% [markdown]
# - 🟨 or 연산자 : 두 조건 중 하나라도 참(True)이면 참 반환 🟨

# %%
print(3 < 5) # --> True
print(10 == 20) # --> False

# 🟩하나만 True 🟩

print(3 < 5 or 10 == 20) # True
# Out:
# True
# False
# True

# %%
print(3 < 5) # --> True
print(10 != 20) # --> True

# 🟩 둘 다 True 🟩

print(3 < 5 or 10 != 20) # True
# Out:
# True
# True
# True

# %% [markdown]
# ### 🟧 삼항 연산자 🟧
# - 🟨 a if 조건식 else b 🟨

# %%
score = 80

print('합격') if score >= 80 else print('불합격')
# Out:
# 합격

# %%
score = 30

print('합격') if score >= 80 else print('불합격')
# Out:
# 불합격

# %% [markdown]
# - 🟩 삼항 연산자 실습 예제 🟩
# 1. 🟦 키보드로 서로 다른 두 개의 정수를 입력 받아 둘 중에 큰 수를 출력하시오. 🟦

# %%
a = int(input('정수 입력 1 >> '))
b = int(input('정수 입력 2 >> '))

# (True가 나왔을 때 실행할 문장) if 조건식 --> True or False else (False가 나왔을 때 실행할 문장)

# a = 3, b = 10
print(f'{b}(이)가 더 크다') if a < b else print(f'{a}(이)가 더 크다')
# Out:
# 정수 입력 1 >> 3
# 정수 입력 2 >> 10
# 10(이)가 더 크다
